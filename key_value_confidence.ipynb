# %%
ocr_results = [[[[182.0, 20.0], [348.0, 20.0], [348.0, 44.0], [182.0, 44.0]],
  ('MEDICard Phils., Inc.', 0.9779890775680542)],
 [[[721.0, 13.0], [925.0, 9.0], [925.0, 30.0], [722.0, 35.0]],
  ('Control CodeIP1164990', 0.8915826678276062)],
 [[[715.0, 35.0], [806.0, 35.0], [806.0, 57.0], [715.0, 57.0]],
  ('Date Recie', 0.9203888773918152)],
 [[[837.0, 33.0], [941.0, 33.0], [941.0, 55.0], [837.0, 55.0]],
  ('01/27/2022', 0.9811736941337585)],
 [[[1040.0, 28.0], [1120.0, 28.0], [1120.0, 50.0], [1040.0, 50.0]],
  ('Rev.00', 0.980959415435791)],
 [[[184.0, 44.0], [336.0, 44.0], [336.0, 66.0], [184.0, 66.0]],
  ('Claims Department', 0.9826067686080933)],
 [[[755.0, 57.0], [819.0, 57.0], [819.0, 79.0], [755.0, 79.0]],
  ('Due', 0.9833266139030457)],
 [[[843.0, 55.0], [941.0, 55.0], [941.0, 79.0], [843.0, 79.0]],
  ('02/10/2022', 0.9510934948921204)],
 [[[1040.0, 48.0], [1153.0, 48.0], [1153.0, 72.0], [1040.0, 72.0]],
  ('22 FEB 2018', 0.962429940700531)],
 [[[60.0, 70.0], [170.0, 70.0], [170.0, 92.0], [60.0, 92.0]],
  ('MediCard.', 0.9277780055999756)],
 [[[175.0, 66.0], [451.0, 61.0], [452.0, 85.0], [175.0, 90.0]],
  ('Daily Receiving Report -ient', 0.9408544898033142)],
 [[[194.0, 107.0], [258.0, 112.0], [255.0, 136.0], [192.0, 131.0]],
  ('000107', 0.9976180195808411)],
 [[[544.0, 107.0], [735.0, 103.0], [735.0, 125.0], [545.0, 129.0]],
  ('Member Code:32278405', 0.9819115400314331)],
 [[[943.0, 101.0], [985.0, 101.0], [985.0, 125.0], [943.0, 125.0]],
  ('Age:', 0.9991755485534668)],
 [[[992.0, 101.0], [1036.0, 101.0], [1036.0, 118.0], [992.0, 118.0]],
  ('47.18', 0.9973937273025513)],
 [[[82.0, 114.0], [182.0, 114.0], [182.0, 136.0], [82.0, 136.0]],
  ('Hospital Code', 0.9709542393684387)],
 [[[657.0, 129.0], [845.0, 122.0], [846.0, 151.0], [658.0, 158.0]],
  (' PILIPINAS KYOHRITSU INC.', 0.9772718548774719)],
 [[[985.0, 123.0], [1166.0, 120.0], [1167.0, 144.0], [985.0, 147.0]],
  ('CARPENA JR., ANTONIO R', 0.9216880202293396)],
 [[[581.0, 142.0], [651.0, 147.0], [649.0, 171.0], [579.0, 166.0]],
  ('Company', 0.9988190531730652)],
 [[[907.0, 133.0], [979.0, 138.0], [977.0, 162.0], [905.0, 157.0]],
  ('Principal:', 0.9914610981941223)],
 [[[75.0, 153.0], [181.0, 148.0], [182.0, 172.0], [76.0, 178.0]],
  ('Hospital Name', 0.9968026876449585)],
 [[[197.0, 149.0], [451.0, 144.0], [452.0, 168.0], [197.0, 173.0]],
  (' MARY MEDIATRIX MEDICAL CENTER', 0.9862622618675232)],
  (' PEC:  / MAXIMUM BENEFIT LIMIT 200,000', 0.9499650001525879)],
 [[[542.0, 370.0], [704.0, 367.0], [704.0, 391.0], [543.0, 394.0]],
  ('Payment Status: PAID', 0.9886294603347778)],
 [[[868.0, 363.0], [1171.0, 359.0], [1171.0, 383.0], [868.0, 387.0]],
  ('Covered Period: 06/01/2021 - 05/31/2022', 0.9761366248130798)],
 [[[122.0, 376.0], [184.0, 376.0], [184.0, 400.0], [122.0, 400.0]],
  ('LOA No.:', 0.9928563237190247)],
 [[[206.0, 376.0], [286.0, 376.0], [286.0, 398.0], [206.0, 398.0]],
  ('L-0621342', 0.9784447550773621)],
 [[[90.0, 418.0], [181.0, 413.0], [182.0, 437.0], [92.0, 442.0]],
  ('Approval No.', 0.9693428874015808)],
 [[[545.0, 409.0], [657.0, 409.0], [657.0, 431.0], [545.0, 431.0]],
  ('For Verification:', 0.9777863621711731)],
 [[[278.0, 461.0], [359.0, 466.0], [358.0, 491.0], [276.0, 485.0]],
  ('Printed By:', 0.965578019618988)],
 [[[392.0, 464.0], [463.0, 464.0], [463.0, 486.0], [392.0, 486.0]],
  ('RODORIA', 0.998875081539154)],
 [[[266.0, 488.0], [361.0, 488.0], [361.0, 510.0], [266.0, 510.0]],
  ('Printed Date:', 0.9898245334625244)],
 [[[392.0, 486.0], [480.0, 486.0], [480.0, 508.0], [392.0, 508.0]],
  ('01/27/2022', 0.999500572681427)]]

# %%
ocr_results2=[[[[407.0, 32.0], [905.0, 34.0], [905.0, 63.0], [407.0, 62.0]],
  ('FAIRVIEW GENERAL HOSPITAL,INC.', 0.9547834992408752)],
 [[[1169.0, 34.0], [1240.0, 34.0], [1240.0, 53.0], [1169.0, 53.0]],
  ('12/14/202', 0.9970046281814575)],
 [[[1168.0, 53.0], [1242.0, 57.0], [1240.0, 81.0], [1167.0, 77.0]],
  ('5:19:18P', 0.9007118940353394)],
 [[[360.0, 72.0], [952.0, 75.0], [952.0, 104.0], [360.0, 101.0]],
  ('Lot 20cor. Mercury St.Brgy.Fairview Quezon City', 0.9442141056060791)],
 [[[498.0, 111.0], [816.0, 113.0], [815.0, 137.0], [498.0, 135.0]],
  ('Tel No.+632939.9689/+63 2939.8764', 0.9631456732749939)],
 [[[585.0, 140.0], [726.0, 142.0], [726.0, 166.0], [584.0, 164.0]],
  ('PhilHealth Accredited', 0.9209537506103516)],
 [[[57.0, 193.0], [338.0, 193.0], [338.0, 217.0], [57.0, 217.0]],
  ('HOSP.REC.NO.2021-0745', 0.9785506725311279)],
 [[[395.0, 193.0], [481.0, 193.0], [481.0, 217.0], [395.0, 217.0]],
  ('SOA NO:', 0.8775168657302856)],
 [[[786.0, 198.0], [897.0, 198.0], [897.0, 217.0], [786.0, 217.0]],
  ('ROOM/BED#', 0.9954704642295837)],
 [[[912.0, 198.0], [1000.0, 198.0], [1000.0, 222.0], [912.0, 222.0]],
  ('Private 4', 0.9459562301635742)],
 [[[60.0, 226.0], [179.0, 226.0], [179.0, 245.0], [60.0, 245.0]],
  ('12/13/21', 0.997814416885376)],
 [[[202.0, 1483.0], [323.0, 1487.0], [322.0, 1509.0], [201.0, 1505.0]],
  ('EMR00138424', 0.9923564791679382)],
 [[[339.0, 1483.0], [419.0, 1487.0], [418.0, 1511.0], [338.0, 1506.0]],
  ('IV PUSH', 0.9294065237045288)],
 [[[812.0, 1490.0], [828.0, 1490.0], [828.0, 1509.0], [812.0, 1509.0]],
  ('1', 0.997033953666687)],
 [[[869.0, 1488.0], [926.0, 1488.0], [926.0, 1512.0], [869.0, 1512.0]],
  ('55.00', 0.9978626370429993)],
 [[[970.0, 1484.0], [1028.0, 1489.0], [1026.0, 1514.0], [968.0, 1510.0]],
  ('55.00', 0.9974819421768188)],
 [[[1177.0, 1487.0], [1235.0, 1492.0], [1233.0, 1516.0], [1175.0, 1511.0]],
  ('55.00', 0.9968789219856262)],
 [[[72.0, 1534.0], [174.0, 1534.0], [174.0, 1558.0], [72.0, 1558.0]],
  ('Page 1of 2', 0.87812340259552)]]

# %%
expected_keys = [
    ['Control Code'],
    ['Date Received', 'Date Recieved'],
    ['Due Date'],
    ['Hospital Code', 'Hospital No'],
    ['Member Code', 'Member No'],
    ['Age'],
    ['Contact no'],
    ['Hospital Name'],
    ['Principal'],
    ['Company'],
    ['Registry No'],
    ['Patient Name','PATIENT NAME'],
    ['Mem Type', 'Member Type'],
    ['Member Status', 'Status'],
    ['Validity'],
    ['Date Admitted','Admission Date','Date/time Admitted'],
    ['Plan'],
    ['Date Discharge','Discharge','Date/time Discharged'],
    ['Room No'],
    ['Admission No'],
    ['Hospitalization Plan'],
    ['Attending Doctor'],
    ['Patient Address','Address'],
    ['DD Limit'],
    ['Checked by RMD'],
    ['SA Amount', 'Amount'],
    ['LOA No.'],
    ['Payment Status', 'Status'],
    ['Covered Period'],
    ['For Verification'],
    ['Approval No.', 'Approval Number'],
    ['Printed By'],
    ['First Name'],
    ['Last Name'],
    ['Middle Name'],
    ['Printed Date'],
    ['Batch/SA No.', 'Batch Number','Batch/SA No'],
    ['Checked by URG']
]

# %%
pip install fuzzywuzzy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz
import cv2

image_path = "/Users/sivagar/Documents/work_projects/general_ocr/key_value/IP1165389 THE MEDICAL CITY SOUTH LUZON (p4) (1page)_page-0004.jpg"
image = cv2.imread(image_path)
document_height, document_width, _ = image.shape
heightthresh=0.009
widththresh=0.075

horizontal_threshold = widththresh*document_width
vertical_threshold = heightthresh*document_height

def extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold):
    extracted_data = {}
    used_indices = set()
    key_coordinates_list= []  #[[key,coordinate],[key,coordinate]] "format"
    # Step 1: Identify Keys
    for key_group in expected_keys:
        for key_variant in key_group:
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:
                    ocr_text = ocr_result[1][0]
                    #confidence = ocr_result[1][1]
                    if fuzz.partial_ratio(key_variant.lower(), ocr_text.lower()) > 90:
                        key_text = ocr_results[idx][1][0]
                        key_coordinates = ocr_results[idx][0]
                        if ":" in key_text and key_text.index(":") < len(key_text) - 1:
                            key_name, value_text = map(str.strip, key_text.split(":", 1))
                            extracted_data[key_variant] = value_text
                        # elif key_text.endswith(":"):
                        #     key_name = key_text.strip(":").strip()
                        #     #extracted_data[key_name] = None
                        #     key_coordinates_list.append([key_variant,key_coordinates])
                        else:
                            #extracted_data[key_text] = None
                            key_coordinates_list.append([key_variant,key_coordinates])
                        used_indices.add(idx)

    print(extracted_data)

    #print(extracted_data)

    # Step 2: Assign Values Based on Coordinates
    for key,key_coordinate in key_coordinates_list:

            value_text = ""  # Initialize an empty string to store the extracted value text for the current key
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:  # Check if the OCR result at the current index has not been used before
                    text_coordinates = ocr_result[0]  # Extract the coordinates of the current OCR result
                    text = ocr_result[1][0].strip()  # Extract the OCRtext and remove leading and trailing spaces
                    #print(f"text:{text},key:{key}")
                    #print(f"text_coordinates:{text_coordinates},key_coordinates:{key_coordinate}")
                    # Check if the text is within the specified vertical and horizontal thresholds from the key coordinates
                    if abs(text_coordinates[0][1] - key_coordinate[0][1]) <= vertical_threshold and \
                      key_coordinate[0][0]  <= text_coordinates[0][0] <= key_coordinate[0][0] + 2*horizontal_threshold:
                        value_text += text + " "  # Add the text to the value_text string with a space separator
                        used_indices.add(idx)  # Mark the current OCR result index as used
                        extracted_data[key] = value_text.strip()
                        break

            # # Assign the key as a value only if a value was found and it's not the same as the key
            # if value_text.strip() and value_text.strip() != key:
               # Update the extracted_data dictionary with the extracted value

    return extracted_data  # Return the final extracted data dictionary


# Example Usage:
extracted_data = extract_key_value(ocr_results, expected_keys,horizontal_threshold, vertical_threshold)
print(extracted_data)
# Out:
# /Users/sivagar/miniconda3/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# {'Member Code': '32278405', 'Principal': 'PRINCIPAL', 'Status': 'PAID', 'DD Limit': 'P 200,000.00', 'Covered Period': '06/01/2021 - 05/31/2022'}
# ...

# %%
extracted_data
# Out:
# {'Member Code': '32278405',
#  'Principal': 'CARPENA JR., ANTONIO R',
#  'Status': 'PAID',
#  'DD Limit': 'P 200,000.00',
#  'Covered Period': '06/01/2021 - 05/31/2022',
#  'Date Recieved': '01/27/2022',
#  'Due Date': '02/10/2022',
#  'Hospital Code': '000107',
#  'Hospital No': 'MARY MEDIATRIX MEDICAL CENTER',
#  'Age': '47.18',
#  'Company': 'PILIPINAS KYOHRITSU INC.',
#  'Patient Name': 'CARPENA JR., ANTONIO R',
#  'Member Status': 'ACTIVE',
#  'Date Admitted': '01/11/2022',
#  'Date Discharge': '01/16/2022',
#  'SA Amount': 'P 109,841.85',
#  'LOA No.': 'L-0621342',
#  'Printed By': 'RODORIA',
#  'Printed Date': '01/27/2022'}

# %%
def calculate_confidence_score(key_coordinate, value_coordinate, value_confidence, horizontal_threshold, vertical_threshold):
    """
    Calculates the confidence score for a key-value pair.

    :param key_coordinate: Coordinate of the key (list of points [[x1, y1], [x2, y2], ...]).
    :param value_coordinate: Coordinate of the value (list of points [[x1, y1], [x2, y2], ...]).
    :param value_confidence: OCR confidence score of the value.
    :param horizontal_threshold: Threshold for horizontal distance to consider key and value on the same line.
    :param vertical_threshold: Threshold for vertical distance to consider key and value on the same line.
    :return: Confidence score (0 to 1).
    """

    # Calculate the horizontal and vertical distance between key and value
    horizontal_distance = abs(value_coordinate[1][0] - key_coordinate[1][0])
    vertical_distance = abs(value_coordinate[0][1] - key_coordinate[0][1])

    # Check if key and value are on the same line
    vertical_distance_factor =  max(0, 1 - (vertical_distance / vertical_threshold))

    # Distance factor (normalized to be between 0 and 1)
    # Assuming that a larger distance reduces confidence
    horizontal_distance_factor = max(0, 1 - (horizontal_distance / 2*horizontal_threshold))

    # Combine factors
    # You might want to adjust the weights based on your specific requirements
    combined_confidence = (
        ( 0.010870634672545374 * value_confidence)
        + (0.14878637884553475 * vertical_distance_factor)
        + (0.06912966786118649 * horizontal_distance_factor) + 0.5378983479444748
    )
    return combined_confidence

# %%
def calculate_average_confidence(confidence_scores: Dict[str, float]) -> float:
    """
    Calculates the average confidence score for all key-value pairs.

    :param confidence_scores: Dictionary containing confidence scores for key-value pairs.
    :return: Average confidence score.
    """
    if not confidence_scores:
        return 0.0

    total_confidence = sum(confidence_scores.values())
    average_confidence = total_confidence / len(confidence_scores)
    return average_confidence

# %%
from typing import List, Tuple, Dict, Union
def extract_key_value(
    ocr_results: List[Tuple[List[List[float]], Tuple[str, float]]],
    expected_keys: List[List[str]],
    horizontal_threshold: float,
    vertical_threshold: float,
) -> Dict[str, Union[str, Tuple[str, float]]]:
    extracted_data = {}
    used_indices = set()
    key_value_confidences = {}  # Store confidence scores for each key-value pair
    key_coordinates_list= []

    # Step 1: Identify Keys and Extract Values
    for key_group in expected_keys:
        for key_variant in key_group:
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:
                    ocr_text, confidence = ocr_result[1]
                    if fuzz.partial_ratio(key_variant.lower(), ocr_text.lower()) > 90:
                        key_text = ocr_text
                        key_coordinates = ocr_result[0]
                        if ":" in key_text and key_text.index(":") < len(key_text) - 1:
                            key_name, value_text = map(str.strip, key_text.split(":", 1))
                            # Assign a higher confidence for key-value pairs in the same bounding box
                            higher_confidence = 0.9 + (0.1 * confidence)  # Example: Base of 0.9 plus a portion of OCR confidence
                            extracted_data[key_variant] = (value_text, min(higher_confidence, 1))  # Ensuring max confidence is 1
                        else:
                            key_coordinates_list.append([key_variant, key_coordinates])
                        used_indices.add(idx)
    #print(extracted_data)
    

    # Step 2: Assign Values Based on Coordinates and Calculate Confidence Scores
    for key, key_coordinate in key_coordinates_list:
        value_text = ""  # Initialize an empty string to store the extracted value text
        value_confidence = 0  # Initialize a variable to store the OCR confidence of the value
        value_coordinate = None  # Initialize a variable to store the coordinates of the value
        for idx, ocr_result in enumerate(ocr_results):
            if idx not in used_indices:
                text_coordinates = ocr_result[0]
                text = ocr_result[1][0].strip()
                text_confidence = ocr_result[1][1]  # OCR confidence score of the text
                #print(f"text:{text},key:{key}")
                #print(f"text_coordinates:{text_coordinates},key_coordinates:{key_coordinate}")
                
                if (
                    abs(text_coordinates[0][1] - key_coordinate[0][1])
                    <= vertical_threshold
                    and key_coordinate[1][0] - horizontal_threshold
                    <= text_coordinates[0][0]
                    <= key_coordinate[1][0] + 2 * horizontal_threshold
                ):
                    value_text += text + " "
                    value_confidence = round(text_confidence,4)
                    value_coordinate = text_coordinates
                    used_indices.add(idx)
                    extracted_data[key] = value_text.strip()
                    break

                

        if value_coordinate:
            # Calculate the horizontal and vertical distance between key and value
            horizontal_distance = abs(value_coordinate[1][0] - key_coordinate[1][0])
            vertical_distance = abs(value_coordinate[0][1] - key_coordinate[0][1])
                
            # Check if key and value are on the same line
            vertical_distance_factor =  round(max(0, 1 - (vertical_distance / vertical_threshold)),4)
            # print(horizontal_distance)
            # print(horizontal_distance/(2*horizontal_threshold))
            # Distance factor (normalized to be between 0 and 1)
            # Assuming that a larger distance reduces confidence
            horizontal_distance_factor = round(max(0.1, 1 - (horizontal_distance / round((2*horizontal_threshold),2))),4)
            #print(horizontal_distance_factor
            print(f"value:{value_text}..... , vertical_factor:{vertical_distance_factor}.....,horizontal_factor:{horizontal_distance_factor}....,ocr_confidence{value_confidence}")
            # Calculate confidence score for the key-value pair
            key_value_confidence = calculate_confidence_score(key_coordinate, value_coordinate, value_confidence, horizontal_threshold, vertical_threshold)
            extracted_data[key] = (value_text.strip(), key_value_confidence)
            key_value_confidences[key] = key_value_confidence  # Store confidence score for the key-value pair
            
    # Calculate average confidence score
    average_confidence = calculate_average_confidence(key_value_confidences)

    return extracted_data, average_confidence # Return the final extracted data dictionary and confidence scores


# Example Usage:
extracted_data,average_confidence = extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold)
print("Extracted Data:", extracted_data)

# # Optionally, if you want to separate the values and confidence scores:
# values = {key: value[0] for key, value in extracted_data.items()}
# confidences = {key: value[1] for key, value in extracted_data.items()}

# print("Values:", values)
# print("Confidence Scores:", confidences)
# Out:
# value:01/27/2022 ..... , vertical_factor:0.8653.....,horizontal_factor:0.2941....,ocr_confidence0.9812
# value:02/10/2022 ..... , vertical_factor:0.8653.....,horizontal_factor:0.3621....,ocr_confidence0.9511
# value:000107 ..... , vertical_factor:0.5286.....,horizontal_factor:0.6026....,ocr_confidence0.9976
# value:MARY MEDIATRIX MEDICAL CENTER ..... , vertical_factor:0.7306.....,horizontal_factor:0.1....,ocr_confidence0.9863
# value:47.18 ..... , vertical_factor:1.0.....,horizontal_factor:0.7333....,ocr_confidence0.9974
# value:CARPENA JR., ANTONIO R ..... , vertical_factor:0.3266.....,horizontal_factor:0.1....,ocr_confidence0.9217
# value:PILIPINAS KYOHRITSU INC. ..... , vertical_factor:0.1246.....,horizontal_factor:0.1....,ocr_confidence0.9773
# value:CARPENA JR., ANTONIO R ..... , vertical_factor:0.7306.....,horizontal_factor:0.1....,ocr_confidence0.9913
# value:ACTIVE ..... , vertical_factor:1.0.....,horizontal_factor:0.6601....,ocr_confidence0.9985
# ...

# %%
print(average_confidence)
# Out:
# 0.6599767537351002

# %%
import pandas as pd
import os

def save_to_csv(data, csv_file_path):
    # Convert new data to DataFrame
    new_df = pd.DataFrame(data)

    if os.path.exists(csv_file_path):
        # Read existing data and append new data
        try:
            existing_df = pd.read_csv(csv_file_path)
            combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        except Exception as e:
            print(f"Error reading the CSV file: {e}")
            return
    else:
        combined_df = new_df

    # Write combined data back to the CSV file
    try:
        combined_df.to_csv(csv_file_path, index=False)
    except Exception as e:
        print(f"Error writing to the CSV file: {e}")

# Rest of your code, including the modified extract_key_value function

# %%
def extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold,excel_file_path):
    extracted_data = {}
    used_indices = set()
    key_value_confidences = {}  # Store confidence scores for each key-value pair
    key_coordinates_list= []

    # Step 1: Identify Keys and Extract Values
    for key_group in expected_keys:
        for key_variant in key_group:
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:
                    ocr_text, confidence = ocr_result[1]
                    if fuzz.partial_ratio(key_variant.lower(), ocr_text.lower()) > 90:
                        key_text = ocr_text
                        key_coordinates = ocr_result[0]
                        if ":" in key_text and key_text.index(":") < len(key_text) - 1:
                            key_name, value_text = map(str.strip, key_text.split(":", 1))
                            # Assign a higher confidence for key-value pairs in the same bounding box
                            higher_confidence = 0.9 + (0.1 * confidence)  # Example: Base of 0.9 plus a portion of OCR confidence
                            extracted_data[key_variant] = (value_text, min(higher_confidence, 1))  # Ensuring max confidence is 1
                        else:
                            key_coordinates_list.append([key_variant, key_coordinates])
                        used_indices.add(idx)
    #print(extracted_data)
    

    # Step 2: Assign Values Based on Coordinates and Calculate Confidence Scores
    for key, key_coordinate in key_coordinates_list:
        value_text = ""  # Initialize an empty string to store the extracted value text
        value_confidence = 0  # Initialize a variable to store the OCR confidence of the value
        value_coordinate = None  # Initialize a variable to store the coordinates of the value
        for idx, ocr_result in enumerate(ocr_results):
            if idx not in used_indices:
                text_coordinates = ocr_result[0]
                text = ocr_result[1][0].strip()
                text_confidence = ocr_result[1][1]  # OCR confidence score of the text
                #print(f"text:{text},key:{key}")
                #print(f"text_coordinates:{text_coordinates},key_coordinates:{key_coordinate}")
                
                if (
                    abs(text_coordinates[0][1] - key_coordinate[0][1])
                    <= vertical_threshold
                    and key_coordinate[1][0] - horizontal_threshold
                    <= text_coordinates[0][0]
                    <= key_coordinate[1][0] + 2 * horizontal_threshold
                ):
                    value_text += text + " "
                    value_confidence = round(text_confidence,4)
                    value_coordinate = text_coordinates
                    print(key_coordinate)
                    if value_coordinate:
                        # Calculate the horizontal and vertical distance between key and value
                        horizontal_distance = abs(value_coordinate[1][0] - key_coordinate[1][0])
                        vertical_distance = abs(value_coordinate[0][1] - key_coordinate[0][1])
                            
                        # Check if key and value are on the same line
                        vertical_distance_factor =  round(max(0, 1 - (vertical_distance / vertical_threshold)),4)
                        horizontal_distance_factor = round(max(0.1, 1 - (horizontal_distance / round((2*horizontal_threshold),2))),4)
                        data_to_save = []
                        data_to_save.append({
                        'key_value': key,
                        'value': value_text,
                        'vertical_factor': vertical_distance_factor,
                        'horizontal_factor': horizontal_distance_factor,
                        'ocr_confidence': value_confidence
                        })
                        save_to_csv(data_to_save, excel_file_path)
                        
                    used_indices.add(idx)
                    extracted_data[key] = value_text.strip()
                    break

                

        

            #print(horizontal_distance_factor
            #print(f"value:{value_text}..... , vertical_factor:{vertical_distance_factor}.....,horizontal_factor:{horizontal_distance_factor}....,ocr_confidence{value_confidence}")
            # Calculate confidence score for the key-value pair
            # key_value_confidence = calculate_confidence_score(key_coordinate, value_coordinate, value_confidence, horizontal_threshold, vertical_threshold)
            # extracted_data[key] = (value_text.strip(), key_value_confidence)

    # data_to_save = []
    # for key, (value_text, confidence) in extracted_data.items():
    #     # # Assuming vertical_distance_factor and horizontal_distance_factor are calculated earlier
    #     # vertical_distance_factor = ...  # Replace with actual calculation
    #     # horizontal_distance_factor = ...  # Replace with actual calculation

    #     data_to_save.append({
    #         'key_value': key,
    #         'value': value_text,
    #         'vertical_factor': vertical_distance_factor,
    #         'horizontal_factor': horizontal_distance_factor,
    #         'ocr_confidence': confidence
    #     })

    # # Call save_to_excel function
    # save_to_csv(data_to_save, excel_file_path)
            
            
    return extracted_data # Return the final extracted data dictionary and confidence scores



excel_file_path = '/Users/sivagar/Documents/work_projects/general_ocr/key_value/data.csv'

# Example Usage:
extracted_data = extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold,excel_file_path)
print("Extracted Data:", extracted_data)
# Out:
# [[715.0, 35.0], [806.0, 35.0], [806.0, 57.0], [715.0, 57.0]]
# [[755.0, 57.0], [819.0, 57.0], [819.0, 79.0], [755.0, 79.0]]
# [[82.0, 114.0], [182.0, 114.0], [182.0, 136.0], [82.0, 136.0]]
# [[75.0, 153.0], [181.0, 148.0], [182.0, 172.0], [76.0, 178.0]]
# [[943.0, 101.0], [985.0, 101.0], [985.0, 125.0], [943.0, 125.0]]
# [[907.0, 133.0], [979.0, 138.0], [977.0, 162.0], [905.0, 157.0]]
# [[581.0, 142.0], [651.0, 147.0], [649.0, 171.0], [579.0, 166.0]]
# [[86.0, 190.0], [184.0, 190.0], [184.0, 214.0], [86.0, 214.0]]
# [[863.0, 177.0], [978.0, 177.0], [978.0, 199.0], [863.0, 199.0]]
# [[82.0, 265.0], [184.0, 265.0], [184.0, 287.0], [82.0, 287.0]]
# [[80.0, 304.0], [184.0, 304.0], [184.0, 326.0], [80.0, 326.0]]
# [[104.0, 339.0], [186.0, 341.0], [186.0, 363.0], [104.0, 361.0]]
# [[122.0, 376.0], [184.0, 376.0], [184.0, 400.0], [122.0, 400.0]]
# [[278.0, 461.0], [359.0, 466.0], [358.0, 491.0], [276.0, 485.0]]
# [[266.0, 488.0], [361.0, 488.0], [361.0, 510.0], [266.0, 510.0]]
# ...

# %%
def extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold,excel_file_path):
    extracted_data = {}
    used_indices = set()
    key_value_confidences = {}  # Store confidence scores for each key-value pair
    key_coordinates_list= []

    # Step 1: Identify Keys and Extract Values
    for key_group in expected_keys:
        for key_variant in key_group:
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:
                    ocr_text, confidence = ocr_result[1]
                    if fuzz.partial_ratio(key_variant.lower(), ocr_text.lower()) > 90:
                        key_text = ocr_text
                        key_coordinates = ocr_result[0]
                        if ":" in key_text and key_text.index(":") < len(key_text) - 1:
                            key_name, value_text = map(str.strip, key_text.split(":", 1))
                            # Assign a higher confidence for key-value pairs in the same bounding box
                            higher_confidence = 0.9 + (0.1 * confidence)  # Example: Base of 0.9 plus a portion of OCR confidence
                            extracted_data[key_variant] = (value_text, min(higher_confidence, 1))  # Ensuring max confidence is 1
                        else:
                            key_coordinates_list.append([key_variant, key_coordinates])
                        used_indices.add(idx)
    #print(extracted_data)
    

    # Step 2: Assign Values Based on Coordinates and Calculate Confidence Scores
    for key, key_coordinate in key_coordinates_list:
        value_text = ""  # Initialize an empty string to store the extracted value text
        value_confidence = 0  # Initialize a variable to store the OCR confidence of the value
        value_coordinate = None  # Initialize a variable to store the coordinates of the value
        for idx, ocr_result in enumerate(ocr_results):
            if idx not in used_indices:
                text_coordinates = ocr_result[0]
                text = ocr_result[1][0].strip()
                text_confidence = ocr_result[1][1]  # OCR confidence score of the text
                #print(f"text:{text},key:{key}")
                #print(f"text_coordinates:{text_coordinates},key_coordinates:{key_coordinate}")
                
                if (
                    abs(text_coordinates[0][1] - key_coordinate[0][1])
                    <= vertical_threshold
                    and key_coordinate[1][0] - horizontal_threshold
                    <= text_coordinates[0][0]
                    <= key_coordinate[1][0] + 2 * horizontal_threshold
                ):
                    value_text += text + " "
                    value_confidence = round(text_confidence,4)
                    value_coordinate = text_coordinates
                    print(key_coordinate)
                    if value_coordinate:
                        # Calculate the horizontal and vertical distance between key and value
                        horizontal_distance = abs(value_coordinate[1][0] - key_coordinate[1][0])
                        vertical_distance = abs(value_coordinate[0][1] - key_coordinate[0][1])
                            
                        # Check if key and value are on the same line
                        vertical_distance_factor =  round(max(0, 1 - (vertical_distance / vertical_threshold)),4)
                        horizontal_distance_factor = round(max(0.1, 1 - (horizontal_distance / round((2*horizontal_threshold),2))),4)
                        data_to_save = []
                        data_to_save.append({
                        'key_value': key,
                        'value': value_text,
                        'vertical_factor': vertical_distance_factor,
                        'horizontal_factor': horizontal_distance_factor,
                        'ocr_confidence': value_confidence
                        })
                        save_to_csv(data_to_save, excel_file_path)
                        
                    used_indices.add(idx)
                    extracted_data[key] = value_text.strip()
                    break

                

        

            #print(horizontal_distance_factor
            #print(f"value:{value_text}..... , vertical_factor:{vertical_distance_factor}.....,horizontal_factor:{horizontal_distance_factor}....,ocr_confidence{value_confidence}")
            # Calculate confidence score for the key-value pair
            # key_value_confidence = calculate_confidence_score(key_coordinate, value_coordinate, value_confidence, horizontal_threshold, vertical_threshold)
            # extracted_data[key] = (value_text.strip(), key_value_confidence)

    # data_to_save = []
    # for key, (value_text, confidence) in extracted_data.items():
    #     # # Assuming vertical_distance_factor and horizontal_distance_factor are calculated earlier
    #     # vertical_distance_factor = ...  # Replace with actual calculation
    #     # horizontal_distance_factor = ...  # Replace with actual calculation

    #     data_to_save.append({
    #         'key_value': key,
    #         'value': value_text,
    #         'vertical_factor': vertical_distance_factor,
    #         'horizontal_factor': horizontal_distance_factor,
    #         'ocr_confidence': confidence
    #     })

    # # Call save_to_excel function
    # save_to_csv(data_to_save, excel_file_path)
            
            
    return extracted_data # Return the final extracted data dictionary and confidence scores



excel_file_path = '/Users/sivagar/Documents/work_projects/general_ocr/key_value/data.csv'

# Example Usage:
extracted_data = extract_key_value(ocr_results, expected_keys, horizontal_threshold, vertical_threshold,excel_file_path)
print("Extracted Data:", extracted_data)
# Out:
# [[715.0, 35.0], [806.0, 35.0], [806.0, 57.0], [715.0, 57.0]]
# [[755.0, 57.0], [819.0, 57.0], [819.0, 79.0], [755.0, 79.0]]
# [[82.0, 114.0], [182.0, 114.0], [182.0, 136.0], [82.0, 136.0]]
# [[75.0, 153.0], [181.0, 148.0], [182.0, 172.0], [76.0, 178.0]]
# [[943.0, 101.0], [985.0, 101.0], [985.0, 125.0], [943.0, 125.0]]
# [[907.0, 133.0], [979.0, 138.0], [977.0, 162.0], [905.0, 157.0]]
# [[581.0, 142.0], [651.0, 147.0], [649.0, 171.0], [579.0, 166.0]]
# [[86.0, 190.0], [184.0, 190.0], [184.0, 214.0], [86.0, 214.0]]
# [[863.0, 177.0], [978.0, 177.0], [978.0, 199.0], [863.0, 199.0]]
# [[82.0, 265.0], [184.0, 265.0], [184.0, 287.0], [82.0, 287.0]]
# [[80.0, 304.0], [184.0, 304.0], [184.0, 326.0], [80.0, 326.0]]
# [[104.0, 339.0], [186.0, 341.0], [186.0, 363.0], [104.0, 361.0]]
# [[122.0, 376.0], [184.0, 376.0], [184.0, 400.0], [122.0, 400.0]]
# [[278.0, 461.0], [359.0, 466.0], [358.0, 491.0], [276.0, 485.0]]
# [[266.0, 488.0], [361.0, 488.0], [361.0, 510.0], [266.0, 510.0]]
# ...

# %%
from typing import List, Tuple, Dict, Union

# %%
def identify_keys_and_extract_values(
    ocr_results: List[Tuple[List[List[float]], Tuple[str, float]]],
    expected_keys: List[List[str]],
) -> Tuple[
    Dict[Union[str, Tuple[str, float]]], List[List[Union[str, List[List[float]]]]]
]:
    extracted_data = {}
    used_indices = set()
    key_coordinates_list = []

    for key_group in expected_keys:
        for key_variant in key_group:
            for idx, ocr_result in enumerate(ocr_results):
                if idx not in used_indices:
                    ocr_text, confidence = ocr_result[1]
                    if fuzz.partial_ratio(key_variant.lower(), ocr_text.lower()) > 90:
                        key_text = ocr_text
                        key_coordinates = ocr_result[0]
                        if ":" in key_text and key_text.index(":") < len(key_text) - 1:
                            key_name, value_text = map(
                                str.strip, key_text.split(":", 1)
                            )
                            higher_confidence = 0.85 + (0.1 * confidence)
                            extracted_data[key_variant] = (
                                value_text,
                                min(higher_confidence, 1),
                            )
                        else:
                            key_coordinates_list.append([key_variant, key_coordinates])
                        used_indices.add(idx)

    return extracted_data, key_coordinates_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sivagar/Documents/work_projects/general_ocr/key_value/key_value_confidence.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/Users/sivagar/Documents/work_projects/general_ocr/key_value/key_value_confidence.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> def identify_keys_and_extract_values(
#       <a href='vscode-notebook-cell:/Users/sivagar/Documents/work_projects/general_ocr/key_value/key_value_confidence.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a>     ocr_results: List[Tuple[List[List[float]], Tuple[str, float]]],
#       <a href='vscode-notebook-cell:/Users/sivagar/Documents/work_projects/general_ocr/key_value/key_value_confidence.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a>     expected_keys: List[List[str]],
# ...
